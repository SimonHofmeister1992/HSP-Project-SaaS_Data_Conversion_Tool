# %%
from exchangelib import DELEGATE, Account, Configuration, Credentials
from exchangelib.autodiscover import AutodiscoverProtocol
import import_ipynb
import login_data as crd
# Out:
# importing Jupyter notebook from login_data.ipynb

# %%
print(crd.credentials)
# Out:
# hos47096

# %%
config = Configuration(server='exchange.othr.de', credentials=crd.credentials)
account = Account(primary_smtp_address='simon1.hofmeister@st.othr.de', config=config,
                  autodiscover=False, access_type=DELEGATE)

# %%
i = 0
for calendar_item in account.calendar.all(): #all().order_by('datetime_received')
    if i == 0:
        print(calendar_item)
    i=i+1
# Out:
# CalendarItem(mime_content=b'BEGIN:VCALENDAR\r\nMETHOD:PUBLISH\r\nPRODID:Microsoft Exchange Server 2010\r\nVERSION:2.0\r\nBEGIN:VTIMEZONE\r\nTZID:W. Europe Standard Time\r\nBEGIN:STANDARD\r\nDTSTART:16010101T030000\r\nTZOFFSETFROM:+0200\r\nTZOFFSETTO:+0100\r\nRRULE:FREQ=YEARLY;INTERVAL=1;BYDAY=-1SU;BYMONTH=10\r\nEND:STANDARD\r\nBEGIN:DAYLIGHT\r\nDTSTART:16010101T020000\r\nTZOFFSETFROM:+0100\r\nTZOFFSETTO:+0200\r\nRRULE:FREQ=YEARLY;INTERVAL=1;BYDAY=-1SU;BYMONTH=3\r\nEND:DAYLIGHT\r\nEND:VTIMEZONE\r\nBEGIN:VEVENT\r\nORGANIZER;CN=hofisi92dev@gmail.com:MAILTO:hofisi92dev@gmail.com\r\nATTACH:CID:3A0A7DF8276C3C438BFF0C904F103DA6@exmail.hs-regensburg.de\r\nDESCRIPTION;LANGUAGE=de-DE:Sie wurden zum folgenden Termin eingeladen.\\nBes\r\n prechung HSP\\nWann    Mi 29. Apr. 2020 2PM \xe2\x80\x93 3PM Mitteleurop\xc3\xa4ische Zeit\r\n  - Berlin\\nWo      zoom-meeting (Karte<https://www.google.com/maps/search/\r\n zoom-meeting?hl=de>)\\nVideoanruf      Beitreten Hangouts\\n        An Video\r\n anruf teilnehmen<https://hangouts.google.com/hangouts/_/calendar/aG9maXNpO\r\n TJkZXZAZ21haWwuY29t.2fillhqo4s48g407be9jitdl3c>\\nKalender        simon1.ho\r\n fmeister@st.othr.de\\nWer     \xe2\x80\xa2       hofisi92dev@gmail.com - Organisator\r\n \\n\xe2\x80\xa2       hofisi92@gmail.com\\n\xe2\x80\xa2       simon1.hofmeister@st.othr.de\\n\\n\r\n Mehr Details \xc2\xbb<https://www.google.com/calendar/event?action=VIEW&eid=MmZp\r\n bGxocW80czQ4ZzQwN2JlOWppdGRsM2Mgc2ltb24xLmhvZm1laXN0ZXJAc3Qub3Roci5kZQ&tok\r\n =MjEjaG9maXNpOTJkZXZAZ21haWwuY29tOWQ4MDZiMDVlMWZjZDM1YjMwMDliNzM0NWVlYjVmN\r\n jAzNGRkYTY5Ng&ctz=Europe%2FBerlin&hl=de&es=0>\\n\\nFortschritte besprechen\\n\r\n Teilnehmen (simon1.hofmeister@st.othr.de)?   Ja<https://www.google.com/cal\r\n endar/event?action=RESPOND&eid=MmZpbGxocW80czQ4ZzQwN2JlOWppdGRsM2Mgc2ltb24\r\n xLmhvZm1laXN0ZXJAc3Qub3Roci5kZQ&rst=1&tok=MjEjaG9maXNpOTJkZXZAZ21haWwuY29t\r\n OWQ4MDZiMDVlMWZjZDM1YjMwMDliNzM0NWVlYjVmNjAzNGRkYTY5Ng&ctz=Europe%2FBerlin\r\n &hl=de&es=0> - Vielleicht<https://www.google.com/calendar/event?action=RES\r\n POND&eid=MmZpbGxocW80czQ4ZzQwN2JlOWppdGRsM2Mgc2ltb24xLmhvZm1laXN0ZXJAc3Qub\r\n 3Roci5kZQ&rst=3&tok=MjEjaG9maXNpOTJkZXZAZ21haWwuY29tOWQ4MDZiMDVlMWZjZDM1Yj\r\n MwMDliNzM0NWVlYjVmNjAzNGRkYTY5Ng&ctz=Europe%2FBerlin&hl=de&es=0> - Nein<ht\r\n tps://www.google.com/calendar/event?action=RESPOND&eid=MmZpbGxocW80czQ4ZzQ\r\n wN2JlOWppdGRsM2Mgc2ltb24xLmhvZm1laXN0ZXJAc3Qub3Roci5kZQ&rst=2&tok=MjEjaG9m\r\n aXNpOTJkZXZAZ21haWwuY29tOWQ4MDZiMDVlMWZjZDM1YjMwMDliNzM0NWVlYjVmNjAzNGRkYT\r\n Y5Ng&ctz=Europe%2FBerlin&hl=de&es=0>    Weitere Optionen \xc2\xbb<https://www.go\r\n ogle.com/calendar/event?action=VIEW&eid=MmZpbGxocW80czQ4ZzQwN2JlOWppdGRsM2\r\n Mgc2ltb24xLmhvZm1laXN0ZXJAc3Qub3Roci5kZQ&tok=MjEjaG9maXNpOTJkZXZAZ21haWwuY\r\n 29tOWQ4MDZiMDVlMWZjZDM1YjMwMDliNzM0NWVlYjVmNjAzNGRkYTY5Ng&ctz=Europe%2FBer\r\n lin&hl=de&es=0>\\nEinladung von Google Kalender<https://www.google.com/cale\r\n ndar/>\\n\\nSie erhalten diese E-Mail unter simon1.hofmeister@st.othr.de\\, d\r\n a Sie ein Gast bei diesem Termin sind.\\n\\nLehnen Sie diesen Termin ab\\, um\r\n  keine weiteren Informationen zu diesem Termin zu erhalten. Sie k\xc3\xb6nnen au\r\n ch unter https://www.google.com/calendar/ ein Google-Konto erstellen und I\r\n hre Benachrichtigungseinstellungen f\xc3\xbcr Ihren gesamten Kalender steuern.\\n\r\n \\nWenn Sie diese Einladung weiterleiten\\, kann jeder Empf\xc3\xa4nger eine Antwo\r\n rt an den Organisator senden und zur G\xc3\xa4steliste hinzugef\xc3\xbcgt werden. Au\xc3\x9f\r\n erdem k\xc3\xb6nnte er weitere Nutzer einladen und Ihre Antwort \xc3\xa4ndern. Weitere\r\n  Informationen<https://support.google.com/calendar/answer/37135#forwarding\r\n >.\\n\r\nUID:2fillhqo4s48g407be9jitdl3c@google.com\r\nSUMMARY;LANGUAGE=de-DE:Einladung: Besprechung HSP - Mi 29. Apr. 2020 2PM - \r\n 3PM (MESZ) (simon1.hofmeister@st.othr.de)\r\nDTSTART;TZID=W. Europe Standard Time:20200429T140000\r\nDTEND;TZID=W. Europe Standard Time:20200429T150000\r\nCLASS ...

# %%
for calendar_item in account.calendar.all(): #all().order_by('datetime_received')
    print('Kalender: ', 'Kalender', ', Termin: ', calendar_item.subject)
for cal in account.calendar.tree().split('\n'):
    while cal[0] < '0' or cal[0] > 'z':
        cal = cal[1:]
    if cal != 'Kalender' and cal != 'Calendar':
        for calendar_item in (account.calendar / cal).all():
            print('Kalender: ', cal, ', Termin: ', calendar_item.subject)
# Out:
# Kalender:  Kalender , Termin:  Einladung: Besprechung HSP - Mi 29. Apr. 2020 2PM - 3PM (MESZ) (simon1.hofmeister@st.othr.de)
# Kalender:  Kalender , Termin:  WIS Herr Hofmeister
# Kalender:  Geburtstage , Termin:  Geburtstag von ads ddsa
# Kalender:  testkalender , Termin:  test-termin
